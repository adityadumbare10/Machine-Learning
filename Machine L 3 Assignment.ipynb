# %% [markdown]
# # Telecom Churn Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rc("font", size=14)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"C:\Users\ds3\Downloads\WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
data.dropna()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data1.Churn.replace({"Yes":1, "No":0}, inplace = True)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Target variables

# %%
data['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
sns.countplot(x='Churn',data=data)
plt.show()

# %%
data.groupby('Churn').mean()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges
# Churn
# 0           0.128721  37.569965       61.265124
# 1           0.254682  17.979133       74.441332

# %%
data.groupby('Contract').mean()
# Out:
#                 SeniorCitizen     tenure  MonthlyCharges     Churn
# Contract
# Month-to-month       0.208258  18.036645       66.398490  0.427097
# One year             0.128988  42.044807       65.048608  0.112695
# Two year             0.085546  56.735103       60.770413  0.028319

# %%
data.groupby('PaymentMethod').mean()
# Out:
#                            SeniorCitizen     tenure  MonthlyCharges     Churn
# PaymentMethod
# Bank transfer (automatic)       0.150907  43.656736       67.192649  0.167098
# Credit card (automatic)         0.145204  43.269382       66.512385  0.152431
# Electronic check                0.251163  25.174630       76.255814  0.452854
# Mailed check                    0.058313  21.830025       43.917060  0.191067

# %%
data.groupby('PaperlessBilling').mean()
# Out:
#                   SeniorCitizen     tenure  MonthlyCharges     Churn
# PaperlessBilling
# No                     0.092618  32.189067       51.992967  0.163301
# Yes                    0.210022  32.496524       73.553776  0.335651

# %% [markdown]
# # Visualization

# %%
# %matplotlib inline
pd.crosstab(data.Contract,data.Churn).plot(kind='bar')
plt.title('churn frequeny based on contract')
plt.xlabel('contract')
plt.ylabel('Frequency of churn')
# Out:
# Text(0, 0.5, 'Frequency of churn')

# %%
# %matplotlib inline
pd.crosstab(data.PaperlessBilling,data.Churn).plot(kind='bar')
plt.title('PaperlessBilling frequeny based on contract')
plt.xlabel('PaperlessBilling ')
plt.ylabel('Frequency of PaperlessBilling')
# Out:
# Text(0, 0.5, 'Frequency of PaperlessBilling')

# %%
# %matplotlib inline
pd.crosstab(data.PaymentMethod,data.Churn).plot(kind='bar')
plt.title('PaymentMethod frequeny based on contract')
plt.xlabel('PaymentMethod')
plt.ylabel('Frequency of PaymentMethod')
# Out:
# Text(0, 0.5, 'Frequency of PaymentMethod')

# %%
pd.set_option("display.max_columns" , 100)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
categorical_variables=['gender','OnlineBackup','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod']
for var in categorical_variables:
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(data[var], prefix=var)
    data1=data.join(cat_list)
    data=data1

# %%
data1.drop(['Partner','Dependents','OnlineBackup','gender','PhoneService','MultipleLines','InternetService','OnlineSecurity','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod'], axis =1  , inplace =True )

# %%
data1
# Out:
#       customerID  SeniorCitizen  tenure  MonthlyCharges TotalCharges  Churn  \
# 0     7590-VHVEG              0       1           29.85        29.85      0
# 1     5575-GNVDE              0      34           56.95       1889.5      0
# 2     3668-QPYBK              0       2           53.85       108.15      1
# 3     7795-CFOCW              0      45           42.30      1840.75      0
# 4     9237-HQITU              0       2           70.70       151.65      1
# ...          ...            ...     ...             ...          ...    ...
# 7038  6840-RESVB              0      24           84.80       1990.5      0
# 7039  2234-XADUH              0      72          103.20       7362.9      0
# 7040  4801-JZAZL              0      11           29.60       346.45      0
# 7041  8361-LTMKD              1       4           74.40        306.6      1
# 7042  3186-AJIEK              0      66          105.65       6844.5      0
#
#       gender_Female  gender_Male  OnlineBackup_No  \
# ...

# %%
data1["TotalCharges"] = data1['TotalCharges'].replace(' ' , 0)

# %%
data1
# Out:
#       customerID  SeniorCitizen  tenure  MonthlyCharges TotalCharges  Churn  \
# 0     7590-VHVEG              0       1           29.85        29.85      0
# 1     5575-GNVDE              0      34           56.95       1889.5      0
# 2     3668-QPYBK              0       2           53.85       108.15      1
# 3     7795-CFOCW              0      45           42.30      1840.75      0
# 4     9237-HQITU              0       2           70.70       151.65      1
# ...          ...            ...     ...             ...          ...    ...
# 7038  6840-RESVB              0      24           84.80       1990.5      0
# 7039  2234-XADUH              0      72          103.20       7362.9      0
# 7040  4801-JZAZL              0      11           29.60       346.45      0
# 7041  8361-LTMKD              1       4           74.40        306.6      1
# 7042  3186-AJIEK              0      66          105.65       6844.5      0
#
#       gender_Female  gender_Male  OnlineBackup_No  \
# ...

# %%
X , y = data1.drop(['Churn', "customerID"], axis = 1 ) , data1['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train , y_test  = train_test_split(X  , y  ,test_size=0.3)

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = log_reg.predict(X_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix
print(classification_report(pred , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1674
#            1       0.54      0.68      0.60       439
#
#     accuracy                           0.81      2113
#    macro avg       0.72      0.76      0.74      2113
# weighted avg       0.83      0.81      0.82      2113

# %%
sns.heatmap(confusion_matrix(pred, y_test))
# Out:
# <AxesSubplot:>
